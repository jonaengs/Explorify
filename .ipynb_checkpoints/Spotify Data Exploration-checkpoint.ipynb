# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import os
import json

# %%
for dirname, _, filenames in os.walk('./data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./data/StreamingHistoryDesi.json
# ./data/StreamingHistoryKaggle.json

# %%
# Create URL to JSON file (alternatively this can be a filepath)
json_file = './data/StreamingHistoryDesi.json'

# Load the first sheet of the JSON file into a data frame
df = pd.read_json(json_file, orient='columns')

# View the first ten rows
df.head(10)
# Out:
#             endTime               artistName  \
# 0  2020-10-13 17:34          Michael Jackson
# 1  2020-10-14 07:07                  Beyoncé
# 2  2020-10-14 07:07     The Pleasure Is Ours
# 3  2020-10-14 07:12           Charlie Wilson
# 4  2020-10-14 07:12  Wolfgang Amadeus Mozart
# 5  2020-10-14 07:12            Jordin Sparks
# 6  2020-10-14 07:12                  Beyoncé
# 7  2020-10-14 07:12        Justin Timberlake
# 8  2020-10-14 07:16        Justin Timberlake
# 9  2020-10-14 07:16          Michael Jackson
#
#                                            trackName  msPlayed
# 0  I Just Can't Stop Loving You (feat. Siedah Gar...     62823
# 1                                          Kitty Kat      1147
# 2  Tim Dillon: Why “Nice Guys Finish Last” Isn’t ...    551075
# 3     Floatin' (feat. Justin Timberlake & will.i.am)      2395
# 4  Mozart / Arr. Grieg for Two Pianos: Piano Sona...      6917
# 5                         No Air (feat. Chris Brown)    264373
# 6                    Crazy In Love - Homecoming Live      1448
# 7                                         True Blood      1119
# 8                                Midnight Summer Jam      1265
# 9  The Girl Is Mine 2008 with will.i.am (with wil...      2624

# %%
print(len(df))
# Out:
# 5489

# %%
# Some stats
print(df["msPlayed"].mean(), df["msPlayed"].min(), df["msPlayed"].max())
# Out:
# 121008.54964474404 0 3508040

# %%
## filter tracks by msPlayed
threshold = 10000  # 10 seconds
fully_listened = df.loc[df['msPlayed'] >= threshold] 
skipped = df.loc[df['msPlayed'] < threshold]

# %%
# ratio skipped and fuly listened
print("Fully listened to %.2f%% \nTotal number of tracks %d" % (len(fully_listened)/len(df)*100, len(fully_listened)))
print("\nSkipped to %.2f%% \nTotal number of tracks %d" % (len(skipped)/len(df)*100, len(skipped)))
# Out:
# Fully listened to 65.04%
# Total number of tracks 3570
#
# Skipped to 34.96%
# Total number of tracks 1919

# %%
fig = plt.figure(figsize=(12, 7))
plt.hist(fully_listened['msPlayed']/100, bins=20,  rwidth=0.9)
fig.suptitle('Listening histogram', fontsize=20)
plt.ylabel('# of songs', fontsize=18)
plt.xlabel('seconds', fontsize=16)
# Out:
# Text(0.5, 0, 'seconds')

# %% [markdown]
# # Spotify API: Extract data and features

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = "b9dbb97e8d404c7ca611adc9aa7814c6"
client_secret = "49de3614d07a4ac5bab51f4c3e836c47"
credentials = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
# token = credentials.get_access_token()

spotify = spotipy.Spotify(auth_manager=credentials)

# %%
# Extract data functions

def get_track_details(row):
    try:
        return spotify.search(q="track:" + row.trackName[:40] + " artist:" + row.artistName, limit=1, type="track")
    except ReadTimeout as e:
        print(row.trackName)
        return None
        

def get_track_features(track_id):
    if track_id is not None:
        return spotify.audio_features(track_id)
    return None

def extract_album_id(track_details):
    try:
        return track_details["tracks"]["items"][0]["album"]["id"]
    except IndexError as e:
        return None
    
def get_track_album_data(album_id):
    try:
        album = spotify.album(album_id)
    except IndexError as e:
        return None

def get_track_genre_by_artist(artist_details):
    try:
        return artist_details["genres"]
    except IndexError as e:
        return None
    
def get_artist_id(track_details):
    try:
        return track_details["tracks"]["items"][0]["album"]["artists"][0]["id"]
    except IndexError as e:
        return None
    
def get_artist_data(artist_id):
    try:
        return spotify.artist(artist_id)
    except ReadTimeout as e:
        print(artist_name)
        return None

def get_track_id(track_details):
    try:
        return track_details['tracks']['items'][0]['id']
    except:
        return None
    
def get_track_duration(track_details):
    try:
        return track_details['tracks']['items'][0]['duration_ms']
    except:
        return None

def get_track_popularity(track_details):
    try:
        return track_details['tracks']['items'][0]['popularity']
    except:
        return None

# %%
fully_listened["trackDetails"] = fully_listened.apply(lambda x: get_track_details(x), axis=1)
fully_listened.head()
# Out:
# /home/iivanova/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#              endTime            artistName  \
# 0   2020-10-13 17:34       Michael Jackson
# 2   2020-10-14 07:07  The Pleasure Is Ours
# 5   2020-10-14 07:12         Jordin Sparks
# 12  2020-10-14 07:16                 Ne-Yo
# 19  2020-10-14 07:21       Oliver Cheatham
#
#                                             trackName  msPlayed  \
# 0   I Just Can't Stop Loving You (feat. Siedah Gar...     62823
# 2   Tim Dillon: Why “Nice Guys Finish Last” Isn’t ...    551075
# 5                          No Air (feat. Chris Brown)    264373
# 12                                          Lie To Me    261812
# 19                            Get Down Saturday Night    234000
#
#                                          trackDetails
# 0   {'tracks': {'href': 'https://api.spotify.com/v...
# 2   {'tracks': {'href': 'https://api.spotify.com/v...
# 5   {'tracks': {'href': 'https://api.spotify.com/v...
# 12  {'tracks': {'href': 'https://api.spotify.com/v...
# 19  {'tracks': {'href': 'https://api.spotify.com/v...

# %%
fully_listened.trackDetails.head()[0]
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3AI+Just+Can%27t+Stop+Loving+You+%28feat.+Sied+artist%3AMichael+Jackson&type=track&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3fMbdgg4jU18AjLCKBhRSm'},
#        'href': 'https://api.spotify.com/v1/artists/3fMbdgg4jU18AjLCKBhRSm',
#        'id': '3fMbdgg4jU18AjLCKBhRSm',
#        'name': 'Michael Jackson',
#        'type': 'artist',
#        'uri': 'spotify:artist:3fMbdgg4jU18AjLCKBhRSm'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/24TAupSNVWSAHL0R7n71vm'},
#      'href': 'https://api.spotify.com/v1/albums/24TAupSNVWSAHL0R7n71vm',
#      'id': '24TAupSNVWSAHL0R7n71vm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731bb21d27effb96a1d0fe8d6d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021bb21d27effb96a1d0fe8d6d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511bb21d27effb96a1d0fe8d6d',
#        'width': 64}],
#      'name': 'Bad 25th Anniversary',
#      'release_date': '1987-08-31',
#      'release_date_precision': 'day',
#      'total_tracks': 24,
#      'type': 'album',
#      'uri': 'spotify:album:24TAupSNVWSAHL0R7n71vm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3fMbdgg4jU18AjLCKBhRSm'},
#       'href': 'https://api.spotify.com/v1/artists/3fMbdgg4jU18AjLCKBhRSm',
#       'id': '3fMbdgg4jU18AjLCKBhRSm',
#       'name': 'Michael Jackson',
#       'type': 'artist',
#       'uri': 'spotify:artist:3fMbdgg4jU18AjLCKBhRSm'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7EVlecngyrLHfQUqFMpwkT'},
#       'href': 'https://api.spotify.com/v1/artists/7EVlecngyrLHfQUqFMpwkT',
#       'id': '7EVlecngyrLHfQUqFMpwkT',
#       'name': 'Siedah Garrett',
#       'type': 'artist',
#       'uri': 'spotify:artist:7EVlecngyrLHfQUqFMpwkT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 251760,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11204987'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2fytePz8UsbUr8n33QBEcm'},
#     'href': 'https://api.spotify.com/v1/tracks/2fytePz8UsbUr8n33QBEcm',
#     'id': '2fytePz8UsbUr8n33QBEcm',
#     'is_local': False,
#     'name': "I Just Can't Stop Loving You (feat. Siedah Garrett) - 2012 Remaster",
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d12ed1b78cd68ef9de0db2eb1052ad354f6e92cd?cid=5ebc7c6206764ba4967f3f76a909ea4c',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:2fytePz8UsbUr8n33QBEcm'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=track%3AI+Just+Can%27t+Stop+Loving+You+%28feat.+Sied+artist%3AMichael+Jackson&type=track&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 5}}

# %%
fully_listened["trackId"] = fully_listened["trackDetails"].apply(get_track_id)
# Out:
# /home/iivanova/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
fully_listened["trackDuration"] = fully_listened["trackDetails"].apply(get_track_duration)
# Out:
# /home/iivanova/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
fully_listened["trackPopularity"] = fully_listened["trackDetails"].apply(get_track_popularity)
# Out:
# /home/iivanova/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
fully_listened["trackAlbum"] = fully_listened["trackDetails"].apply(extract_album_id)
# Out:
# /home/iivanova/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
fully_listened["trackArtistId"] = fully_listened["trackDetails"].apply(get_artist_id)
# Out:
# /home/iivanova/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
fully_listened["trackFeatures"] = fully_listened["trackId"].apply(lambda x: get_track_features(x))
# Out:
# /home/iivanova/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
fully_listened.head()
# Out:
#              endTime            artistName  \
# 0   2020-10-13 17:34       Michael Jackson
# 2   2020-10-14 07:07  The Pleasure Is Ours
# 5   2020-10-14 07:12         Jordin Sparks
# 12  2020-10-14 07:16                 Ne-Yo
# 19  2020-10-14 07:21       Oliver Cheatham
#
#                                             trackName  msPlayed  \
# 0   I Just Can't Stop Loving You (feat. Siedah Gar...     62823
# 2   Tim Dillon: Why “Nice Guys Finish Last” Isn’t ...    551075
# 5                          No Air (feat. Chris Brown)    264373
# 12                                          Lie To Me    261812
# 19                            Get Down Saturday Night    234000
#
#                                          trackDetails                 trackId  \
# 0   {'tracks': {'href': 'https://api.spotify.com/v...  2fytePz8UsbUr8n33QBEcm
# 2   {'tracks': {'href': 'https://api.spotify.com/v...                    None
# 5   {'tracks': {'href': 'https://api.spotify.com/v...  1jUA4rb6ZCv4gby4YU53xq
# 12  {'tracks': {'href': 'https://api.spotify.com/v...  1esIJxNe8G5uljudKAuKn6
# 19  {'tracks': {'href': 'https://api.spotify.com/v...  0awG4a7t5UrmZZ4PZVNav3
#
#     trackDuration  trackPopularity              trackAlbum  \
# 0        251760.0             66.0  24TAupSNVWSAHL0R7n71vm
# 2             NaN              NaN                    None
# 5        264373.0             72.0  6JCNOvp9UeMrFuXwNW0JW6
# 12       267093.0             35.0  6dTn9vJSxVTIGm4Cu5dH4x
# 19       234000.0             59.0  5aVya3XGTKxxuOA4LT5Ayz
#
#                                         trackFeatures           trackArtistId
# 0   [{'danceability': 0.657, 'energy': 0.467, 'key...  3fMbdgg4jU18AjLCKBhRSm
# 2                                                None                    None
# 5   [{'danceability': 0.466, 'energy': 0.759, 'key...  2AQjGvtT0pFYfxR3neFcvz
# 12  [{'danceability': 0.623, 'energy': 0.661, 'key...  21E3waRsmPlU7jZsS13rcj
# 19  [{'danceability': 0.883, 'energy': 0.674, 'key...  0LyfQWJT6nXafLPZqxe9Of

# %%
# clean-up None values
filtered = fully_listened.loc[fully_listened["trackId"].notna()]
print("Just cleaned up %d tracks" % (fully_listened.shape[0] - filtered.shape[0]))
# Out:
# Just cleaned up 193 tracks

# %%
filtered.drop("trackDetails", axis=1, inplace=True)
filtered.head()
# Out:
# /home/iivanova/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#              endTime       artistName  \
# 0   2020-10-13 17:34  Michael Jackson
# 5   2020-10-14 07:12    Jordin Sparks
# 12  2020-10-14 07:16            Ne-Yo
# 19  2020-10-14 07:21  Oliver Cheatham
# 23  2020-10-14 07:23          Beyoncé
#
#                                             trackName  msPlayed  \
# 0   I Just Can't Stop Loving You (feat. Siedah Gar...     62823
# 5                          No Air (feat. Chris Brown)    264373
# 12                                          Lie To Me    261812
# 19                            Get Down Saturday Night    234000
# 23                               Get Me Bodied - Live    137651
#
#                    trackId  trackDuration  trackPopularity  \
# 0   2fytePz8UsbUr8n33QBEcm       251760.0             66.0
# 5   1jUA4rb6ZCv4gby4YU53xq       264373.0             72.0
# 12  1esIJxNe8G5uljudKAuKn6       267093.0             35.0
# 19  0awG4a7t5UrmZZ4PZVNav3       234000.0             59.0
# 23  7Bd6JQ2Evmeuw4cPYUtcEz       263008.0             49.0
#
#                 trackAlbum                                      trackFeatures  \
# 0   24TAupSNVWSAHL0R7n71vm  [{'danceability': 0.657, 'energy': 0.467, 'key...
# 5   6JCNOvp9UeMrFuXwNW0JW6  [{'danceability': 0.466, 'energy': 0.759, 'key...
# 12  6dTn9vJSxVTIGm4Cu5dH4x  [{'danceability': 0.623, 'energy': 0.661, 'key...
# 19  5aVya3XGTKxxuOA4LT5Ayz  [{'danceability': 0.883, 'energy': 0.674, 'key...
# 23  35S1JCj5paIfElT2GODl6x  [{'danceability': 0.822, 'energy': 0.935, 'key...
#
#              trackArtistId
# 0   3fMbdgg4jU18AjLCKBhRSm
# 5   2AQjGvtT0pFYfxR3neFcvz
# 12  21E3waRsmPlU7jZsS13rcj
# 19  0LyfQWJT6nXafLPZqxe9Of
# 23  6vWDO969PvNqNYHIOW5v0m

# %%
# Extract Artist Data
artist_data = {}
for i, row in filtered.iterrows():
    artist_id = row["trackArtistId"]
    if artist_id not in artist_data:
        artist_details = get_artist_data(artist_id)
        artist_data[artist_id] = {"name": artist_details["name"],
                                  "genres": artist_details["genres"],
                                  "popularity": artist_details["popularity"],
                                  "followers": artist_details["followers"]}

# %%
# Extract Artist Data
album_data = {}
for i, row in filtered.iterrows():
    artist_id = row["trackArtistId"]
    if artist_id not in artist_data:
        artist_details = get_artist_data(artist_id)
        artist_data[artist_id] = {"name": artist_details["name"],
                                  "genres": artist_details["genres"],
                                  "popularity": artist_details["popularity"],
                                  "followers": artist_details["followers"]}

# %%
with open("./data/track_data.txt", "r") as f:
    tracks = json.load(f)

# %%
track_fetures = {}

# %%
for name, track_info in tracks.items():
    track_fetures[track_info["id"]] = spotify.audio_features(track_info["id"])

# %%
with open("./data/track_feature_data.txt", "w") as f:
    json.dump(track_fetures, f)

# %%
from multiprocessing import  Pool
from functools import partial
import numpy as np

def parallelize(data, func, num_of_processes=10):
    data_split = np.array_split(data, num_of_processes)
    pool = Pool(num_of_processes)
    data = pd.concat(pool.map(func, data_split))
    pool.close()
    pool.join()
    return data

def run_on_subset(func, data_subset):
    return data_subset.apply(func, axis=1)

def parallelize_on_rows(data, func, num_of_processes=10):
    return parallelize(data, partial(run_on_subset, func), num_of_processes)

# %%
fully_listened["trackDetails"] = parallelize_on_rows(fully_listened, get_track_details)
# Out:
# /home/iivanova/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
